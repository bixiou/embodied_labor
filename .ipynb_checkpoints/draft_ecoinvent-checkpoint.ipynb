# %%
from pandas import read_pickle

# %%
path_ecoinvent = '/media/adrien/dd/adrien/DD/Économie/Données/A_ecoinvent_3_2_substitution'

# %%
A = read_pickle(path_ecoinvent+'/A.pkl')
LABEL = read_pickle(path_ecoinvent+'/label_A_idx.pkl')
# substitute the original URI A's index and column by the LABEL's ones.
A.index, A.columns = LABEL.index, LABEL.index

# %%
# if necessary, substitute the nan value into 0
A = A.fillna(0)

# %%
LABEL.to_excel('label.xls')

# %%
list(A.index)
# Out:
# [('Sea and coastal water transportation services',
#   'transport, freight, sea, transoceanic ship [GLO]',
#   'transport, freight, sea, transoceanic ship',
#   'metric ton*km'),
#  ('Sea and coastal water transportation services',
#   'market for transport, freight, sea, liquefied natural gas [GLO]',
#   'transport, freight, sea, liquefied natural gas',
#   'metric ton*km'),
#  ('Sea and coastal water transportation services',
#   'market for transport, freight, sea, transoceanic ship [GLO]',
#   'transport, freight, sea, transoceanic ship',
#   'metric ton*km'),
#  ('Sea and coastal water transportation services',
#   'transport, freight, sea, transoceanic tanker [GLO]',
#   'transport, freight, sea, transoceanic tanker',
#   'metric ton*km'),
#  ('Sea and coastal water transportation services',
#   'transport, freight, sea, liquefied natural gas [GLO]',
#   'transport, freight, sea, liquefied natural gas',
#   'metric ton*km'),
#  ('Sea and coastal water transportation services',
# ...
